# %%
import kagglehub
import os
import pandas as pd

path = kagglehub.dataset_download("nathansmallcalder/lol-match-history-and-summoner-data-80k-matches")

print(os.listdir(path))

champion = pd.read_csv(path + "/ChampionTbl.csv")
item = pd.read_csv(path + "/ItemTbl.csv")
matchstats = pd.read_csv(path + "/MatchStatsTbl.csv")
matchtbl = pd.read_csv(path + "/MatchTbl.csv")
ranking = pd.read_csv(path + "/RankTbl.csv")
summoner = pd.read_csv(path + "/SummonerMatchTbl.csv")
team = pd.read_csv(path + "/TeamMatchTbl.csv")
# Out:
# ['ChampionTbl.csv', 'ItemTbl.csv', 'MatchStatsTbl.csv', 'MatchTbl.csv', 'RankTbl.csv', 'SummonerMatchTbl.csv', 'TeamMatchTbl.csv']

# %%
champion.columns
# Out:
# Index(['ChampionId', 'ChampionName'], dtype='str')

# %%
item.columns
# Out:
# Index(['ItemID', 'ItemName'], dtype='str')

# %%
matchstats.columns
# Out:
# Index(['MatchStatsId', 'SummonerMatchFk', 'MinionsKilled', 'DmgDealt',
#        'DmgTaken', 'TurretDmgDealt', 'TotalGold', 'Lane', 'Win', 'item1',
#        'item2', 'item3', 'item4', 'item5', 'item6', 'kills', 'deaths',
#        'assists', 'PrimaryKeyStone', 'PrimarySlot1', 'PrimarySlot2',
#        'PrimarySlot3', 'SecondarySlot1', 'SecondarySlot2', 'SummonerSpell1',
#        'SummonerSpell2', 'CurrentMasteryPoints', 'EnemyChampionFk',
#        'DragonKills', 'BaronKills', 'visionScore'],
#       dtype='str')

# %%
matchtbl.columns
# Out:
# Index(['MatchId', 'Patch', 'QueueType', 'RankFk', 'GameDuration'], dtype='str')

# %%
ranking.columns
# Out:
# Index(['RankId', 'RankName'], dtype='str')

# %%
summoner.columns
# Out:
# Index(['SummonerMatchId', 'SummonerFk', 'MatchFk', 'ChampionFk'], dtype='str')

# %%
team.columns
# Out:
# Index(['TeamID', 'MatchFk', 'B1Champ', 'B2Champ', 'B3Champ', 'B4Champ',
#        'B5Champ', 'R1Champ', 'R2Champ', 'R3Champ', 'R4Champ', 'R5Champ',
#        'BlueBaronKills', 'BlueRiftHeraldKills', 'BlueDragonKills',
#        'BlueTowerKills', 'BlueKills', 'RedBaronKills', 'RedRiftHeraldKills',
#        'RedDragonKills', 'RedTowerKills', 'RedKills', 'RedWin', 'BlueWin'],
#       dtype='str')

# %%
champ_enemy = champion.rename(columns={
    "ChampionId": "EnemyChampionFk",
    "ChampionName": "EnemyChampion"
})

champ_player = champion.rename(columns={
    "ChampionId": "ChampionFk",
    "ChampionName": "PlayerChampion"
})
item1 = item.rename(columns={"ItemID":"item1","ItemName" : "ItemSlot1"})
item2 = item.rename(columns={"ItemID":"item2","ItemName" : "ItemSlot2"})
item3 = item.rename(columns={"ItemID":"item3","ItemName" : "ItemSlot3"})
item4 = item.rename(columns={"ItemID":"item4","ItemName" : "ItemSlot4"})
item5 = item.rename(columns={"ItemID":"item5","ItemName" : "ItemSlot5"})
item6 = item.rename(columns={"ItemID":"item6","ItemName" : "ItemSlot6"})

# %%
item1.head(1)
# Out:
#   PlayerChampion EnemyChampion    ItemSlot1  MinionsKilled  MatchStatsId  \
# 0          Milio       Caitlyn  Dream Maker             30             1
#
#    SummonerMatchFk  DmgDealt  DmgTaken  TurretDmgDealt  TotalGold    Lane  \
# 0                1      4765     12541               0       7058  BOTTOM
#
#    Win  item1  item2  item3  item4  item5  item6  kills  deaths  assists  \
# 0    0   3870   2055   3107   3171   6620   2022      0       2       12
#
#    PrimaryKeyStone  PrimarySlot1  PrimarySlot2  PrimarySlot3  SecondarySlot1  \
# 0             8465          8463          8473          8453            8345
#
#    SecondarySlot2  SummonerSpell1  SummonerSpell2  CurrentMasteryPoints  \
# 0            8347               4               7                   902
#
#    EnemyChampionFk  DragonKills  BaronKills  visionScore  SummonerMatchId  \
# 0               51            0           0           67              1.0
#
#    SummonerFk          MatchFk  ChampionFk   item1
# 0         1.0  EUW1_7565751492       902.0  3870.0

# %%
partida = (
    matchstats
    .merge(champ_enemy, on="EnemyChampionFk", how="left")
    .merge(summoner, left_on="SummonerMatchFk", right_on="SummonerMatchId", how="left")
    .merge(champ_player, on="ChampionFk", how="left")
    .merge(item1, on = "item1", how="left")
    .merge(item2, on = "item2", how="left")
    .merge(item3, on = "item3", how="left")
    .merge(item4, on = "item4", how="left")
    .merge(item5, on = "item5", how="left")
    .merge(item6, on = "item6", how="left")
    .merge(matchtbl, left_on="MatchFk", right_on="MatchId", how="left")
)

cols = ["PlayerChampion", "EnemyChampion","ItemSlot1","ItemSlot2","ItemSlot3","ItemSlot4","ItemSlot5","ItemSlot6","QueueType","MinionsKilled"] + [
    c for c in partida.columns if c not in ["QueueType","ItemSlot1","ItemSlot2","ItemSlot3","ItemSlot4","ItemSlot5","ItemSlot6","MinionsKilled", "PlayerChampion", "EnemyChampion"]
]


partida = partida[cols]

partida.head(10)
# Out:
#   PlayerChampion EnemyChampion          ItemSlot1              ItemSlot2  \
# 0          Milio       Caitlyn        Dream Maker           Control Ward
# 1          Milio        Lucian        Dream Maker  Shurelya's Battlesong
# 2         Soraka         Xayah        Dream Maker             Redemption
# 3           Ahri      Malphite  Luden's Companion     Rabadon's Deathcap
# 4            Mel       Alistar         Perplexity     Zhonya's Hourglass
# 5      Lissandra          Ornn     Guardian's Orb     Zhonya's Hourglass
# 6          Milio      Aphelios        Dream Maker           Control Ward
# 7           Nami        Ezreal        Dream Maker  Shurelya's Battlesong
# 8          Milio         Sivir        Dream Maker             Redemption
# 9        Leblanc        Twitch  Luden's Companion     Zhonya's Hourglass
#
#                ItemSlot3                 ItemSlot4           ItemSlot5  \
# 0             Redemption          Crimson Lucidity     Echoes of Helia
# 1             Redemption  Ionian Boots of Lucidity     Echoes of Helia
# 2           Giant's Belt          Crimson Lucidity   Moonstone Renewer
# 3            Shadowflame          Sorcerer's Shoes                 NaN
# 4      Liandry's Anguish           Blackfire Torch  Rabadon's Deathcap
# 5             Runecarver          Sorcerer's Shoes  Rabadon's Deathcap
# 6        Echoes of Helia  Ionian Boots of Lucidity        Oblivion Orb
# 7                    NaN  Ionian Boots of Lucidity    Imperial Mandate
# 8  Shurelya's Battlesong  Ionian Boots of Lucidity     Echoes of Helia
# 9       Sorcerer's Shoes                Stormsurge  Rabadon's Deathcap
#
#                       ItemSlot6 QueueType  MinionsKilled  MatchStatsId  \
# 0                  Glowing Mote   CLASSIC             30             1
# 1                  Oblivion Orb   CLASSIC             29             2
# 2                  Oblivion Orb   CLASSIC             34             3
# 3                           NaN      ARAM             51             4
# 4                    Runecarver    CHERRY              0             5
# 5  Crown of the Shattered Queen    CHERRY              0             6
# 6                     Kindlegem   CLASSIC             28             7
# 7                           NaN   CLASSIC             36             8
# 8                  Oblivion Orb   CLASSIC             31             9
# 9            Hextech Alternator      ARAM             42            10
#
#    SummonerMatchFk  DmgDealt  DmgTaken  TurretDmgDealt  TotalGold    Lane  \
# 0                1      4765     12541               0       7058  BOTTOM
